# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('./icecream_flavors.csv')

# %%
df2 = df[['week', 'units sold', 'flavor']].head(20)
df2
week = df2['week']
unitSoled = df2['units sold']
flavor = df2['flavor']
week
df2
# Out:
#     week  units sold      flavor
# 0      1           6   chocolate
# 1      1          15       lemon
# 2      1          12  strawberry
# 3      1           6     vanilla
# 4      2          16   chocolate
# 5      2           7       lemon
# 6      2           7  strawberry
# 7      2          18     vanilla
# 8      3           5   chocolate
# 9      3           8       lemon
# 10     3           4  strawberry
# 11     3           9     vanilla
# 12     4          20   chocolate
# 13     4          12       lemon
# 14     4           1  strawberry
# 15     4          14     vanilla
# 16     5           4   chocolate
# 17     5          20       lemon
# 18     5          18  strawberry
# 19     5           7     vanilla

# %%
sns.lmplot(x='week', y='units sold', data=df)

# %%
sns.barplot(x='week', y='units sold', data=df2)
# Out:
# <AxesSubplot:xlabel='week', ylabel='units sold'>
